# %%
# importing the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
import os
import sklearn

# %% [markdown]
# The Dataset is Taken from Kaggle and the link for the same is https://www.kaggle.com/chetankv/dogs-cats-images

# %%
# let's plot 5 random cat images
import random

cat_path = './Data/training_set/cats/'

for i in range(5):
    n = random.randint(1, 4000)
    plt.figure()
    plt.title("Cat")
    plt.imshow(cv2.imread(cat_path + 'cat.' + str(n) + '.jpg', cv2.IMREAD_COLOR))

# %%
# let's plot 5 random dog images

dog_path = './Data/training_set/dogs/'

for i in range(5):
    n = random.randint(1, 4000)
    plt.figure()
    plt.title("Dog")
    plt.imshow(cv2.imread(dog_path + 'dog.' + str(n) + '.jpg', cv2.IMREAD_COLOR))

# %%
X = [] # To store images
y = [] # To store labels

# labels -
# 0 - Cat
# 1 - Dog

for entry in os.scandir(cat_path):
    img = cv2.imread(cat_path + entry.name, cv2.IMREAD_COLOR)
    img = cv2.resize(img, (96, 96))
    img = np.array(img, dtype='float32')
    X.append(img)
    y.append(0)

# %%
for entry in os.scandir(dog_path):
    img = cv2.imread(dog_path + entry.name, cv2.IMREAD_COLOR)
    img = cv2.resize(img, (96, 96))
    img = np.array(img, dtype='float32')
    X.append(img)
    y.append(1)

# %%
X = np.array(X)

# %%
X.shape # We have 8000 images in total (4000 of each)
# Out:
# (8000, 96, 96, 3)

# %%
y = np.array(y)
y.shape
# Out:
# (8000,)

# %%
# Normalization
X/=255

# %% [markdown]
# ## Image Augmentation

# %% [markdown]
# Image Augmentation (creating new image samples from previous samples) is performed to increase the generalising capability of our model

# %%
# Original Image
plt.imshow(X[0])

# %%
# randomly increasing the brightness
X_new = np.clip(random.uniform(0.5, 2)* X[0], 0.0, 1.0)

# %%
# Augmented Image
plt.imshow(X_new)

# %%
# rotating the images by 180 Degree
X_new = np.flip(X[0], axis = 0)
plt.imshow(X_new)

# %%
# rotating the images by 90 Degree
X_new = np.rot90(X[0])
plt.imshow(X_new)

# %% [markdown]
# We are going to perform these 3 types of image augmentation on 2000 images (1000 of each label)

# %%
X_aug = [] # to store augmented images
y_aug = [] # to store labels of augmented images

for i in range(2000, 6000):
    X_new = np.clip(random.uniform(0.5, 2)* X[i], 0.0, 1.0)
    X_aug.append(X_new)
    y_aug.append(y[i])
    
for i in range(1000, 2000):
    X_new = np.flip(X[i], axis = 0)
    X_aug.append(X_new)
    y_aug.append(y[i])
    
for i in range(6000, 7000):
    X_new = np.flip(X[i], axis = 0)
    X_aug.append(X_new)
    y_aug.append(y[i])
    
for i in range(0, 1000):
    X_new = np.rot90(X[i])
    X_aug.append(X_new)
    y_aug.append(y[i])
    
for i in range(7000, 8000):
    X_new = np.rot90(X[i])
    X_aug.append(X_new)
    y_aug.append(y[i])
    
X_aug = np.array(X_aug)
y_aug = np.array(y_aug)

# %%
X = np.append(X, X_aug, axis=0) # appending augmented images to original list
X.shape
# Out:
# (16000, 96, 96, 3)

# %%
y = np.append(y, y_aug, axis=0)
y.shape
# Out:
# (16000,)

# %%
X_test = [] # To store images
y_test = [] # To store labels

# labels -
# 0 - Cat
# 1 - Dog

cat_path = './Data/test_set/cats/'
dog_path = './Data/test_set/dogs/'

for entry in os.scandir(cat_path):
    img = cv2.imread(cat_path + entry.name, cv2.IMREAD_COLOR)
    img = cv2.resize(img, (96, 96))
    img = np.array(img, dtype='float32')
    X_test.append(img)
    y_test.append(0)
    
for entry in os.scandir(dog_path):
    img = cv2.imread(dog_path + entry.name, cv2.IMREAD_COLOR)
    img = cv2.resize(img, (96, 96))
    img = np.array(img, dtype='float32')
    X_test.append(img)
    y_test.append(1)
    
X_test = np.array(X_test)
X_test/=255
y_test = np.array(y_test)

# %% [markdown]
# ## Splitting the data

# %%
from sklearn.model_selection import train_test_split

# %%
# Taking 50% data for validation 50% for testing 
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size = 0.50, stratify=y_test, shuffle=True)

# %%
y_val.shape
# Out:
# (1000,)

# %%
y_test.shape
# Out:
# (1000,)

# %% [markdown]
# ## Creating and Training the Model

# %%
model = keras.Sequential([
    keras.layers.Conv2D(filters=96, kernel_size=(2,2), activation='relu', input_shape=(96, 96, 3)),
    keras.layers.MaxPooling2D((2,2)),
    
    keras.layers.ZeroPadding2D(padding=(1, 1)),
    keras.layers.Conv2D(filters=192, kernel_size=(3,3), activation='relu', padding='valid'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Dropout(0.2), # for regularization
    
    keras.layers.Conv2D(filters=384, kernel_size=(4,4), activation='relu'),
    keras.layers.MaxPooling2D((3,3)),
    keras.layers.Dropout(0.4),
    
    keras.layers.Conv2D(filters=384, kernel_size=(5,5), activation='relu'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Dropout(0.3),
    
    keras.layers.Flatten(), # flattening for feeding into ANN
    keras.layers.Dense(384, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(192, activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(96, activation='relu'),
    keras.layers.Dense(48, activation='relu'),
    keras.layers.Dense(2, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 95, 95, 96)        1248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 47, 47, 96)        0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 49, 49, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 47, 47, 192)       166080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 192)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 192)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 384)       1180032
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 384)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 384)         3686784
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 384)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 384)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 384)               0
# _________________________________________________________________
# dense (Dense)                (None, 384)               147840
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 384)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 192)               73920
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 192)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 96)                18528
# _________________________________________________________________
# dense_3 (Dense)              (None, 48)                4656
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 98
# =================================================================
# Total params: 5,279,186
# Trainable params: 5,279,186
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt=keras.optimizers.Adam(learning_rate=0.000065)

# %%
# compile the model
model.compile(loss = 'sparse_categorical_crossentropy', optimizer=opt, metrics= ["accuracy"])

# %%
# using early stopping to exit training if validation loss is not decreasing even after certain epochs (patience)
earlystopping = keras.callbacks.EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 10)

# save the best model with lower validation loss
checkpointer = keras.callbacks.ModelCheckpoint(filepath = "DogvsCat_weights.hdf5", verbose = 1, save_best_only=True)

# %%
history = model.fit(X, y, epochs=100, batch_size=128, validation_data=(X_val, y_val), callbacks=[checkpointer, earlystopping])
# Out:
# Epoch 1/100
#   2/125 [..............................] - ETA: 14s - loss: 0.7021 - accuracy: 0.4727WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0120s vs `on_train_batch_end` time: 0.2225s). Check your callbacks.
# 125/125 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5097
# Epoch 00001: val_loss improved from inf to 0.69272, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 31s 244ms/step - loss: 0.6936 - accuracy: 0.5097 - val_loss: 0.6927 - val_accuracy: 0.5020
# Epoch 2/100
# 125/125 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.5143
# Epoch 00002: val_loss improved from 0.69272 to 0.69068, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 29s 236ms/step - loss: 0.6916 - accuracy: 0.5143 - val_loss: 0.6907 - val_accuracy: 0.5520
# Epoch 3/100
# 125/125 [==============================] - ETA: 0s - loss: 0.6827 - accuracy: 0.5577
# Epoch 00003: val_loss improved from 0.69068 to 0.66935, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 30s 237ms/step - loss: 0.6827 - accuracy: 0.5577 - val_loss: 0.6693 - val_accuracy: 0.6000
# Epoch 4/100
# 125/125 [==============================] - ETA: 0s - loss: 0.6627 - accuracy: 0.5969
# Epoch 00004: val_loss improved from 0.66935 to 0.64568, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 31s 250ms/step - loss: 0.6627 - accuracy: 0.5969 - val_loss: 0.6457 - val_accuracy: 0.6440
# Epoch 5/100
# 125/125 [==============================] - ETA: 0s - loss: 0.6377 - accuracy: 0.6371
# Epoch 00005: val_loss improved from 0.64568 to 0.63688, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 30s 242ms/step - loss: 0.6377 - accuracy: 0.6371 - val_loss: 0.6369 - val_accuracy: 0.6390
# Epoch 6/100
# 125/125 [==============================] - ETA: 0s - loss: 0.5995 - accuracy: 0.6770
# Epoch 00006: val_loss improved from 0.63688 to 0.55569, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 31s 247ms/step - loss: 0.5995 - accuracy: 0.6770 - val_loss: 0.5557 - val_accuracy: 0.7130
# Epoch 7/100
# 125/125 [==============================] - ETA: 0s - loss: 0.5631 - accuracy: 0.7113
# Epoch 00007: val_loss improved from 0.55569 to 0.53500, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 30s 240ms/step - loss: 0.5631 - accuracy: 0.7113 - val_loss: 0.5350 - val_accuracy: 0.7420
# Epoch 8/100
# 125/125 [==============================] - ETA: 0s - loss: 0.5367 - accuracy: 0.7330
# Epoch 00008: val_loss improved from 0.53500 to 0.47934, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 31s 245ms/step - loss: 0.5367 - accuracy: 0.7330 - val_loss: 0.4793 - val_accuracy: 0.7780
# Epoch 9/100
# 125/125 [==============================] - ETA: 0s - loss: 0.4972 - accuracy: 0.7618
# Epoch 00009: val_loss improved from 0.47934 to 0.44510, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 31s 244ms/step - loss: 0.4972 - accuracy: 0.7618 - val_loss: 0.4451 - val_accuracy: 0.8050
# Epoch 10/100
# 125/125 [==============================] - ETA: 0s - loss: 0.4697 - accuracy: 0.7815
# Epoch 00010: val_loss improved from 0.44510 to 0.41538, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 31s 246ms/step - loss: 0.4697 - accuracy: 0.7815 - val_loss: 0.4154 - val_accuracy: 0.8200
# Epoch 11/100
# 125/125 [==============================] - ETA: 0s - loss: 0.4419 - accuracy: 0.7988
# Epoch 00011: val_loss improved from 0.41538 to 0.39539, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 30s 239ms/step - loss: 0.4419 - accuracy: 0.7988 - val_loss: 0.3954 - val_accuracy: 0.8320
# Epoch 12/100
# 125/125 [==============================] - ETA: 0s - loss: 0.4209 - accuracy: 0.8094
# Epoch 00012: val_loss improved from 0.39539 to 0.39471, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 30s 239ms/step - loss: 0.4209 - accuracy: 0.8094 - val_loss: 0.3947 - val_accuracy: 0.8290
# Epoch 13/100
# 125/125 [==============================] - ETA: 0s - loss: 0.3956 - accuracy: 0.8201
# Epoch 00013: val_loss improved from 0.39471 to 0.37749, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 30s 239ms/step - loss: 0.3956 - accuracy: 0.8201 - val_loss: 0.3775 - val_accuracy: 0.8350
# Epoch 14/100
# 125/125 [==============================] - ETA: 0s - loss: 0.3814 - accuracy: 0.8324
# Epoch 00014: val_loss improved from 0.37749 to 0.36086, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 30s 239ms/step - loss: 0.3814 - accuracy: 0.8324 - val_loss: 0.3609 - val_accuracy: 0.8350
# Epoch 15/100
# 125/125 [==============================] - ETA: 0s - loss: 0.3572 - accuracy: 0.8457
# Epoch 00015: val_loss did not improve from 0.36086
# 125/125 [==============================] - 30s 238ms/step - loss: 0.3572 - accuracy: 0.8457 - val_loss: 0.3652 - val_accuracy: 0.8400
# Epoch 16/100
# 125/125 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.8506
# Epoch 00016: val_loss improved from 0.36086 to 0.36056, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 30s 239ms/step - loss: 0.3444 - accuracy: 0.8506 - val_loss: 0.3606 - val_accuracy: 0.8360
# Epoch 17/100
# 125/125 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8677
# Epoch 00017: val_loss did not improve from 0.36056
# 125/125 [==============================] - 30s 238ms/step - loss: 0.3157 - accuracy: 0.8677 - val_loss: 0.4209 - val_accuracy: 0.8190
# Epoch 18/100
# 125/125 [==============================] - ETA: 0s - loss: 0.2903 - accuracy: 0.8804
# Epoch 00018: val_loss improved from 0.36056 to 0.33992, saving model to DogvsCat_weights.hdf5
# 125/125 [==============================] - 30s 239ms/step - loss: 0.2903 - accuracy: 0.8804 - val_loss: 0.3399 - val_accuracy: 0.8490
# Epoch 19/100
# 125/125 [==============================] - ETA: 0s - loss: 0.2726 - accuracy: 0.8894
# Epoch 00019: val_loss did not improve from 0.33992
# 125/125 [==============================] - 30s 238ms/step - loss: 0.2726 - accuracy: 0.8894 - val_loss: 0.4184 - val_accuracy: 0.8260
# Epoch 20/100
# 125/125 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.8946
# Epoch 00020: val_loss did not improve from 0.33992
# 125/125 [==============================] - 30s 238ms/step - loss: 0.2580 - accuracy: 0.8946 - val_loss: 0.3411 - val_accuracy: 0.8430
# Epoch 21/100
# 125/125 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.9079
# Epoch 00021: val_loss did not improve from 0.33992
# 125/125 [==============================] - 31s 248ms/step - loss: 0.2318 - accuracy: 0.9079 - val_loss: 0.3425 - val_accuracy: 0.8590
# Epoch 22/100
# 125/125 [==============================] - ETA: 0s - loss: 0.2067 - accuracy: 0.9194
# Epoch 00022: val_loss did not improve from 0.33992
# 125/125 [==============================] - 31s 245ms/step - loss: 0.2067 - accuracy: 0.9194 - val_loss: 0.3727 - val_accuracy: 0.8400
# Epoch 23/100
# 125/125 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9242
# Epoch 00023: val_loss did not improve from 0.33992
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1902 - accuracy: 0.9242 - val_loss: 0.3503 - val_accuracy: 0.8600
# Epoch 24/100
# 125/125 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.9354
# Epoch 00024: val_loss did not improve from 0.33992
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1722 - accuracy: 0.9354 - val_loss: 0.3581 - val_accuracy: 0.8610
# Epoch 25/100
# 125/125 [==============================] - ETA: 0s - loss: 0.1578 - accuracy: 0.9394
# Epoch 00025: val_loss did not improve from 0.33992
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1578 - accuracy: 0.9394 - val_loss: 0.3587 - val_accuracy: 0.8640
# Epoch 26/100
# 125/125 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9484
# Epoch 00026: val_loss did not improve from 0.33992
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1393 - accuracy: 0.9484 - val_loss: 0.4890 - val_accuracy: 0.8330
# Epoch 27/100
# 125/125 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9474
# Epoch 00027: val_loss did not improve from 0.33992
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1375 - accuracy: 0.9474 - val_loss: 0.3665 - val_accuracy: 0.8590
# Epoch 28/100
# 125/125 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 0.9549
# Epoch 00028: val_loss did not improve from 0.33992
# 125/125 [==============================] - 30s 238ms/step - loss: 0.1227 - accuracy: 0.9549 - val_loss: 0.3903 - val_accuracy: 0.8630
# Epoch 00028: early stopping

# %%
# saving the model architecture to json file for future use

model_json = model.to_json()
with open("DogvsCat-model.json","w") as json_file:
  json_file.write(model_json)

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,29)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = history.history['accuracy']
accuracy_val = history.history['val_accuracy']
epochs = range(1,29)
plt.plot(epochs, accuracy_train, 'g', label='Training Accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing the Best Trained Model

# %%
with open('DogvsCat-model.json', 'r') as json_file:
    json_savedModel= json_file.read()

# load the model architecture 
model = tf.keras.models.model_from_json(json_savedModel)
model.load_weights('DogvsCat_weights.hdf5')
model.compile(optimizer = "Adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])

# %%
predictions = model.predict(X_test)

# %%
predicted = []

for i in predictions:
    predicted.append(np.argmax(i))

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       500
#            1       0.88      0.89      0.89       500
#
#     accuracy                           0.89      1000
#    macro avg       0.89      0.89      0.88      1000
# weighted avg       0.89      0.89      0.88      1000

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cf_matrix = confusion_matrix(y_test, predicted)
plt.figure(figsize = (7,7))

group_names = ['Cats Predicted Correctly','Cats Predicted as Dogs','Dogs Predicted as Cats','Dogs Predicted Correctly']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
# Out:
# <AxesSubplot:>
